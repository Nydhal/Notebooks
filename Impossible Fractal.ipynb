# %%
#control width of screen
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:99% !important; }</style>"))
# Out:
# <style>.container { width:99% !important; }</style>

# %%
s=['w','w','w','w','w','w','w','r','r','g','w','w','w','w','w','w','w',
   'w','w','w','w','w','w','r','r','g','g','g','w','w','w','w','w','w',
   'w','w','w','w','w','r','r','g','g','b','g','g','w','w','w','w','w',
   'w','w','w','w','r','r','g','g','w','b','b','g','g','w','w','w','w',
   'w','w','w','r','r','r','r','r','r','r','b','b','g','g','w','w','w',
   'w','w','r','r','g','b','b','b','b','b','r','r','g','g','g','w','w',
   'w','r','r','g','g','b','g','g','w','r','r','g','g','b','g','g','w',
   'r','r','g','g','w','b','b','g','g','r','g','g','w','b','b','g','g',
   'r','r','r','r','r','r','b','b','g','r','r','r','r','r','b','b','g',
   'g','b','b','b','b','b','b','b','b','b','b','b','b','b','r','r','g',
   'g','b','g','g','w','w','w','w','w','w','w','w','w','r','r','g','g']
leng = len(s)-20
rule = {''.join(s[i:i+7]):s[i+20] for i in range(leng) }

curr = 70*'w'+'rrg'+70*'w'
width = range(len(curr))

for i in range(70):
    print("Gen %3i:  %s" % ( i, curr.replace('w',' ')\
                            .replace('r','\x1b[31m█\x1b[0m')\
                            .replace('g','\x1b[32m█')\
                            .replace('b','\x1b[34m█') ))
    curr = 'www' + curr + 'www'
    curr = ''.join(rule[curr[i:i+7]] for i in width)
# Out:
# Gen   0:                                                                        ███
# Gen   1:                                                                       █████
# Gen   2:                                                                      ███████
# Gen   3:                                                                     ████ ████
# Gen   4:                                                                    ███████████
# Gen   5:                                                                   █████████████
# Gen   6:                                                                  ███████ ███████
# Gen   7:                                                                 ████ ███████ ████
# Gen   8:                                                                ███████████████████
# Gen   9:                                                               █████████████████████
# ...
